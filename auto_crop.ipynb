# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamShaswat/TCS-Humain/blob/master/auto_crop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 #Opencv
from PIL import Image #Image from PIL
import glob
import os


from google.colab.patches import cv2_imshow
import pandas as pd

# %%
import face_recognition
#!pip install face_recognition

# %%
#crop the face from ima

class FaceCropper(object):
    CASCADE_PATH = "haarcascade_frontalface_default.xml"

    def __init__(self):
        self.face_cascade = cv2.CascadeClassifier(self.CASCADE_PATH)

    def generate(self, image_path, show_result):
        img = cv2.imread(image_path)
        if (img is None):
            print("Can't open image file")
            return 0

        #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
       
        image = face_recognition.load_image_file(image_path)
        faces = face_recognition.face_locations(image)
        if (faces is None):
            print('Failed to detect face')
            return 0

        if (show_result):
          for (top, right, bottom, left) in face_locations:
            cv2.rectangle(image_cv, (left, top), (right, bottom), (0, 0, 255), 2)
            cv2_imshow( img)
            cv2.waitKey(0)
            cv2.destroyAllWindows()

        facecnt = len(faces)
        print("Detected faces: %d" % facecnt)
        i = 0
        height, width = img.shape[:2]

        for (top, right, bottom, left) in face_locations:
  
            

            faceimg = img[top:bottom, left:right]
            #lastimg = cv2.resize(faceimg, (48, 48))
            i += 1
         
            cv2.imwrite(('crop_im/'+image_path.split('/')[1].replace('.jpg','')+'_c%d.jpg'% i),faceimg)

# %%
#make dir
# !mkdir crop_im

# %%
#list all the imahes
names=os.listdir('images')

# %%
#cropin the face and savin it
for name in names:
  FaceCropper().generate(os.path.join('images/',name),False)

# %%
#read csv file
data=pd.read_csv('Face_Recognition.csv')

# %%
image_path="images/701.jpg"
image = face_recognition.load_image_file(image_path)

face_locations=face_recognition.face_locations(image)

image_cv=cv2.imread(image_path)
i=1
for (top, right, bottom, left) in face_locations:
  cv2.rectangle(image_cv, (left, top), (right, bottom), (0, 0, 255), 2)
  cv2.imwrite((image_path.split('/')[1].replace('.jpg','')+'c%d.jpg'% i),image_cv[top:bottom, left:right])
  i+=1
    
  cv2_imshow(image_cv[top:bottom, left:right])
# Out:
# <PIL.Image.Image image mode=RGB size=268x268 at 0x7F9538BA1208>

# %%
data[661:703]
# Out:
#                                                content  ...     metadata__last_updated_by
# 661  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...  HWbICv9u4uSnWrU830DjuF7FfMK2
# 662                                                NaN  ...                           NaN
# 663  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...  HWbICv9u4uSnWrU830DjuF7FfMK2
# 664                                                NaN  ...                           NaN
# 665                                                NaN  ...                           NaN
# 666                                                NaN  ...                           NaN
# 667                                                NaN  ...                           NaN
# 668                                                NaN  ...                           NaN
# 669  http://com.dataturks.a96-i23.open.s3.amazonaws...  ...  HWbICv9u4uSnWrU830DjuF7FfMK2
# ...
